# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#conjunto de datos
dataset = pd.read_csv('Salaries.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
dataset.drop(['Unnamed: 0', 'rank','discipline','yrs.since.phd','sex'], axis=1,inplace=True) #Eliminamos las columnas que no utilizaremos

# %%
dataset.head()
# Out:
#    yrs.service  salary
# 0           18  139750
# 1           16  173200
# 2            3   79750
# 3           39  115000
# 4           41  141500

# %%
x = dataset.iloc[:, :-1].values #Creamo las variables independientes y dependientes con los datos de los años de experiencia y el salario
y = dataset.iloc[:, 1].values

# %%
x
# Out:
# array([[18],
#        [16],
#        [ 3],
#        [39],
#        [41],
#        [ 6],
#        [23],
#        [45],
#        [20],
#        [18],
#        [ 8],
#        [ 2],
#        [ 1],
#        [ 0],
#        [18],
#        [ 3],
#        [20],
#        [34],
#        [23],
#        [36],
#        [26],
#        [31],
#        [30],
#        [19],
#        [ 8],
#        [ 8],
#        [23],
#        [ 3],
#        [ 0],
#        [ 8],
#        [ 4],
#        [ 2],
#        [ 9],
#        [ 2],
#        [ 2],
#        [ 0],
#        [21],
#        [ 4],
#        [31],
#        [ 9],
#        [ 2],
#        [23],
#        [27],
#        [38],
#        [19],
#        [15],
#        [28],
#        [19],
#        [25],
#        [ 1],
#        [28],
#        [11],
#        [ 3],
#        [ 9],
#        [11],
#        [ 5],
#        [21],
#        [ 8],
#        [ 9],
#        [ 3],
#        [ 8],
#        [ 2],
#        [31],
#        [11],
#        [ 3],
#        [ 8],
# ...

# %%
y
# Out:
# array([139750, 173200,  79750, 115000, 141500,  97000, 175000, 147765,
#        119250, 129000, 119800,  79800,  77700,  78000, 104800, 117150,
#        101000, 103450, 124750, 137000,  89565, 102580,  93904, 113068,
#         74830, 106294, 134885,  82379,  77000, 118223, 132261,  79916,
#        117256,  80225,  80225,  77000, 155750,  86373, 125196, 100938,
#        146500,  93418, 101299, 231545,  94384, 114778,  98193, 151768,
#        140096,  70768, 126621, 108875,  74692, 106639, 103760,  83900,
#        117704,  90215, 100135,  75044,  90304,  75243, 109785, 103613,
#         68404, 100522, 101000,  99418, 111512,  91412, 126320, 146856,
#        100131,  92391, 113398,  73266, 150480, 193000,  86100,  84240,
#        150743, 135585, 144640,  88825, 122960, 132825, 152708,  88400,
#        172272, 107008,  97032, 105128, 105631, 166024, 123683,  84000,
#         95611, 129676, 102235, 106689, 133217, 126933, 153303, 127512,
# ...

# %%
#Graficamos los datos para ver la dispoersion de los mismos
plt.scatter(x, y)
plt.xlabel('Años de Servicio')
plt.ylabel('Salario')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#Algoritmo a usar
from sklearn import datasets, linear_model
lr = linear_model.LinearRegression()

# %%
#Entrenamientos dle modleo
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#RAqui se predice
Y_pred = lr.predict(X_test)

# %%
Y_pred
# Out:
# array([127146.95487605, 130667.23937571, 106905.31900297, 128907.09712588,
#        108665.4612528 , 113945.8880023 , 114825.95912722, 100744.82112855,
#        124506.7415013 , 124506.7415013 , 121866.52812655, 144748.37737438,
#        105145.17675314, 120986.45700163, 122746.59925147, 113945.8880023 ,
#        106905.31900297, 106905.31900297, 129787.1682508 , 118346.24362688,
#         99864.75000364, 108665.4612528 ,  98104.6077538 , 131547.31050063,
#        113945.8880023 , 105145.17675314, 104265.10562822, 106025.24787805,
#        106025.24787805, 120106.38587672, 120986.45700163, 120986.45700163,
#        100744.82112855, 103385.0345033 , 104265.10562822, 135947.66612521,
#        135947.66612521, 106025.24787805, 116586.10137705, 113065.81687738,
#        118346.24362688, 108665.4612528 , 105145.17675314, 112185.74575247,
#        107785.39012789, 120106.38587672, 118346.24362688, 113945.8880023 ,
# ...

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, Y_pred, color='red', linewidth=3)
plt.title('Regresión Lineal Simple')
plt.ylabel('Sueldo')
plt.xlabel('Años de Servicio')
plt.show()
